# %% [markdown]
# <a href="https://colab.research.google.com/github/ShlomoLibo/FoundationsOfDeepLearning/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# !git clone https://ShlomoLibo:password@github.com/ShlomoLibo/FoundationsOfDeepLearning.git
# Out:
# Cloning into 'FoundationsOfDeepLearning'...
# ...
